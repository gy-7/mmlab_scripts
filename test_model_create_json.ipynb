# %%
 # !pip install torch==1.7.0+cu110 torchvision==0.8.1+cu110 torchaudio==0.7.0 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# install mmcv-full thus we could use CUDA operators
# !pip install mmcv-full -f https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/index.html

# %%
# !git clone https://github.com/open-mmlab/mmdetection.git
# %cd mmdetection
# !pip install -e .

# %% [markdown]
# ## 数据集迁移到工作目录

# %%
# !mkdir data
# !cp -r /kaggle/input/logodetection/val/val/ data/

# %% [markdown]
# ## 下载权重

# %%
# !mkdir work_dirs
# !wget https://www.kaggleusercontent.com/kf/93216930/eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..2_kyfEMV3_Qck_vCommRgw.IzHGU8gRXLDJa7sen_qd77UQx4Fpcm01zhuCPWPGi-y1fRyXCJ0bTg9Xfcv1pR8C75kz0Pf5FJQv01rnWKHQVlCUWsjbKz0VTJEaXfNpwVYyfvwkP02vX3GKu4QH6vvOkr1cGNBmfYBEJxH_Pu0fStlvPBw3KAXAdji1kCJX-h0M5NZJdiLuMcDgC_95n1wAfkhuw_f4bgr9DHhjwASi2akkxF2g7Nj_83jNhq6_2q4hoRnOePt-R-YA28-yCYgCJitCJxEEcSj6_XI9prgFEyAAdExV-FL5TlIJrOo_ap1OXio2RrwiywoHILU-sY78T7qqj86Q6HzETabevC55CjVi328MCxvnsJtX_rHhsLuwneWTzc78YCExN4WIBRArHs9haNUDej2MfzAmwqZ4ZoaEYsXCjLUOCKWxvfwEMfSfMjbFCL8be8kg8cxfj_u7sveJ7OcAqh4cTwjtLIMHxpB_62-38QN5NGQRlnGzHboN4NAQ5eC8orRUYWiK6bv3hFhRrZyH9_Ph2amX8wxeL3Gk9djYVAW_zx8V0Ius66vmu6xajex98y5SryxJ4XUxN39fBlEwvSmmlhdPIsf-Tt0QjioaIfm7zuethr1IN04ZDDjr1M-tiMs_UlB3p5P6T2AJJc00fj2jDEhsyWA_YcS-C7SR_polVPgNhnSwnMQ.LlYULSB86mqf1hJtBHux5w/mmdetection/work_dirs/epoch_15.pth -O ./work_dirs/best.pth

# %% [markdown]
# # 下载配置文件

# %%
# !wget https://files.cnblogs.com/files/blogs/471668/cascade_mask_rcnn_r101_fpn_mstrain_3x_coco_v2_test.zip
# !unzip -d work_dirs/ cascade_mask_rcnn_r101_fpn_mstrain_3x_coco_v2_test.zip
# !mv work_dirs/cascade_mask_rcnn_r101_fpn_mstrain_3x_coco_v2.py work_dirs/config.py

# %%
# !pip install tree
# !tree work_dirs

# %%
# !python tools/test.py work_dirs/config.py work_dirs/best.pth --format-only --eval "bbox" --options "jsonfile_prefix=work_dirs/eva"

# %%
# !cp work_dirs/eva.bbox.json /kaggle/working/
# !cp work_dirs/eva.segm.json /kaggle/working/

# %%
# !tree work_dirs

# %%
# !python tools/test.py work_dirs/config.py work_dirs/best.pth --eval bbox --options "jsonfile_prefix=work_dirs/eva"
